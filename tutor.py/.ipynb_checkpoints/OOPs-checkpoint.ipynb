# %%
class Atm: 
# constructor 
    def __init__(self): 
        self.pin='' 
        self.balance=0
        self.menu() 
    def menu(self): 
        user_input=int(input('''
        Hello, 
        How can I help you! 
        Please,Choose Any one.
        1.Press 1 to Balance Inquiry
        2.Press 2 to Case withdraw
        3.Press 3 to Pin Change
        4.Press 4 to Create Pin
        5.Any things else to exist'''))

# %%
obj=Atm()
# Out:
#         Hello,
#         How can I help you!
#         Please,Choose Any one.
#         1.Press 1 to Balance Inquiry
#         2.Press 2 to Case withdraw
#         3.Press 3 to Pin Change
#         4.Press 4 to Create Pin
#         5.Any things else to exist 5

# %%
print(type(obj)) #this show object belongs to Atm class.
# Out:
# <class '__main__.Atm'>
