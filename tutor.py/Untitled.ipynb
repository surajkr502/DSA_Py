# %%
class stack: 
    def __init__(self): 
        self.stack=[]
    def push(self,element): 
        print(self.stack)
    #     if not self.stack:
    #         self.stack.append(element)
    #         return
    #     else: 
    #         print('Stack is not initialize')
        
obj=stack()
print(obj.stack)
item=input('Enter any values')
obj.push(item)
print(obj.push(item))
print(obj.stack)
# Out:
# []
# Enter any values 4
# []
# []
# None
# []

# %%
class stack: 
    def __init__(self): 
        self.stack=[]
    def push(self,element):
        if self.stack is not None: 
            self.stack.append(element)
            
        else:
            print('welcome')
    def pop(self): 
        if len(self.stack)>0: 
            return self.stack.pop()

        else: 
            # raise IndexError('stack is empty')
            # raise Exception('Stack is empty')
            print('Stack is empty')
            
        
obj=stack()
# item=input('Enter any values')
# obj.push(item)
# print(obj.push(item))
print(obj.stack)
print(obj.pop())
# Out:
# []
# Stack is empty
# None

# %%
obj=stack.__new__(stack)
print(id(obj))
print(id(stack))
# Out:
# 2087033804816
# 2086990034784
