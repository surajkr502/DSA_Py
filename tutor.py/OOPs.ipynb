# %%
class Atm: 
# constructor 
    def __init__(self):#Non parameterize constructor(not required parameter) 
        print(id(self))
        self.pin='123' 
        self.balance=10000
        # self.menu() 
    def menu(self): 
        user_input=input('''
         Hello, 
         How can I help you! 
         Please Choose Any one option.
         1.Press 1 to Balance Inquiry
         2.Press 2 to Case withdraw
         3.Press 3 to Pin Change
         4.Press 4 to Create Pin
         5.Any things else to exist''')
        if user_input=='1': 
            self.Balance_inquiry()
        elif user_input=='2':
            self.case_withdraw()
        elif user_input=='3': 
            self.Change_pin()
        elif user_input=='4': 
            self.create_pin() 
        else:
            exit()
    def create_pin(self): 
        user_pin=input("Enter Your Pin:")
        self.pin=user_pin
        user_balance=input("Enter Your Balance:")
        self.balance=user_balance
        print("pin created successfully")
        self.menu()
    def Change_pin(self): 
        old_pin=input("Enter your old pin:")
        
        if old_pin==self.pin: 
            new_pin=input("Enter new pin:")
            self.pin=new_pin
            print("New pin created successful")
            self.menu()
        else:
            print("Incorrect pin Please try again....")
            self.menu()
    def Balance_inquiry(self): 
        user_pin=input("Enter Your pin:")
        if user_pin==self.pin: 
            print("Your Balance is:",self.balance)
            self.menu()
        else: 
            print("Incorrect pin Please try again....")
            self.menu() 
    def case_withdraw(self): 
        user_pin=input("Enter Your pin:")
        if user_pin==self.pin: 
            req_bal=int(input("Enter Amount:"))
            if req_bal<=self.balance: 
                print("Collect Your Cash:")
                self.balance=self.balance-req_bal
                print("Remaing Balance is:",self.balance)
                self.menu()
            else: 
                print("Insufficient balance.....")
                self.menu()
        else:
            print("Incorrect pin please Try again.....")
            self.menu()

# %%
obj1=Atm()
# Out:
# 2076354561680

# %%
print(id(obj1)) #it means self is obj.
# Out:
# 2076354561680

# %%
obj2=Atm() #we create another obj.
# Out:
# 2076344571600

# %%
#same add shows. 
print(id(obj2))#self sirf present obj ko point out karta hai.
# Out:
# 2076344571600

# %%
print(type(obj)) #this show object belongs to Atm class.
# Out:
# <class '__main__.Atm'>

# %% [markdown]
# ### Fraction

# %%
class fraction: 
    def __init__(self,x,y): 
        self.num=x
        self.den=y

# %%
fr1=fraction(5,4)

# %%
print(type(fr1))
# Out:
# <class '__main__.fraction'>

# %%
print(fr1)

# %%
class fraction: 
    def __init__(self,x,y): 
        self.num=x
        self.den=y
    def __str__(self): #when we try to print fr1 then outomaticaly print the return value inside the __str__
        return 'king'

# %%
fr1=fraction(4,5)

# %%
print(fr1)
# Out:
# king

# %%
class fraction: 
    def __init__(self,x,y): 
        self.num=x
        self.den=y
    def __str__(self): 
        return '{}/{}'.format(self.num,self.den) #using formating form
fr1=fraction(4,5)

# %%
fr2=fraction(1,2)

# %%
print(fr1)
print(fr2)
# Out:
# 4/5
# 1/2

# %%
class fraction: 
    def __init__(self,x,y): 
        self.num=x
        self.den=y
    # def __str__(self): 
    #     return '{}/{}'.format(self.num,self.den)
    def __add__(self,other): 
        new_num=self.num*other.den+other.num*self.den
        new_dem=self.den*other.den
        return '{}/{}'.format(new_num,new_dem)
    def __sub__(self,other): 
        new_num=self.num*other.den-other.num*self.den
        new_dem=self.den*other.den
        return '{}/{}'.format(new_num,new_dem) 
    def __mul__(self,other): 
        new_num=self.num*other.num
        new_dem=self.den*other.den
        return '{}/{}'.format(new_num,new_dem)
    def __truediv__(self,other): 
        new_num=self.num*other.den
        new_dem=self.den*other.num
        return '{}/{}'.format(new_num,new_dem)
    def convert_to_decimal(self):
        return self.num/self.den

# %%
print(fr1)
print(fr2)

# %%
fr1=fraction(3,4)
fr2=fraction(1,2)

# %%
print(fr1+fr2)
# Out:
# 10/8

# %%
print(fr1-fr2)
# Out:
# 2/8

# %%
print(fr1*fr2)
# Out:
# 3/8

# %%
print(fr1/fr2)
# Out:
# 6/4

# %%
fr1.convert_to_decimal()
# Out:
# 0.75

# %%
class Student:
    def __init__(self, name, age):  
        self.name = name           
        self.age = age

    def show(self):                 
        print(self.name, self.age)

s1 = Student("Rahul", 20)
s1.show()
# Out:
# Rahul 20

# %%
#Write a program to find the factorial of any number. 
n=int(input('Enter any Integer No.'))
fact=0
mul=1
for i in range(1,n+1): 
    mul=mul*i
    fact=fact+mul
print(fact)
# Out:
# Enter any Integer No. 5
# 153
